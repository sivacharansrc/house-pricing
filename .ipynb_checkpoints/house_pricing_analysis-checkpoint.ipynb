# %%
import sys
import pandas as pd
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('expand_frame_repr', False)
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import os
import datetime as dt
import sklearn

# %%
file_list = os.listdir("C:\\Users\\sivac\\Documents\\Analytics\\house-pricing\\input-data\\")
for i in file_list:
    i = "C:\\Users\\sivac\\Documents\\Analytics\\house-pricing\\input-data\\" + i
    file = pd.read_csv(i)
    
    if 'df' in globals():
        df = pd.concat([df, file])
    else:
        df = file

print(f'Raw dataset shape: {df.shape}')

df = df.drop_duplicates().reset_index(drop=True)
print(f'Raw dataset shape with duplicates removed: {df.shape}')

df_new = df[['ARCH','BEDROOMS','BATHROOMS','HALF_BATHROOMS','BASE_AREA','TOTAL_AREA','BASEMENT_AREA','BASEMENT_FINISHED_AREA',
             'PARKING_AREA', 'YRBLT','PHYS','QUALITY_CODE', 'LOT_SIZE', 'LAND_VALUE', 'LAST_SALE_PRICE', 'LAST_SALE_DATE', 
             'MARKET_VALUE', 'USPF']].copy()
df_new.head()
# Out:
# Raw dataset shape: (586, 34)
# Raw dataset shape with duplicates removed: (293, 34)
#    ARCH  BEDROOMS  BATHROOMS  HALF_BATHROOMS  BASE_AREA  TOTAL_AREA  \
# 0  2STY       4.0        4.0             1.0       3622        3622
# 1  2STY       6.0        4.0             1.0       3506        3506
# 2  2STY       4.0        3.0             1.0       2587        2587
# 3  2STY       4.0        2.0             1.0       2544        2544
# 4  2STY       4.0        3.0             1.0       2766        2766
#
#    BASEMENT_AREA  BASEMENT_FINISHED_AREA  PARKING_AREA  YRBLT  PHYS  \
# 0           1645                      54           651   2012     8
# 1           1768                       0           630   2013     7
# 2           1180                      75           420   2007     8
# 3           1232                       0           400   2010    11
# 4           1291                      71           400   2008     8
#
#    QUALITY_CODE  LOT_SIZE  LAND_VALUE  LAST_SALE_PRICE  \
# 0            45      0.22       58000           550000
# 1            40      0.21       58000           435000
# 2            40      0.21       58000           364900
# 3            35      0.14       58000           315000
# 4            35      0.18       58000           355000
#
#                LAST_SALE_DATE  MARKET_VALUE    USPF
# 0  Aug 25 2020 12:00:00:000AM     561275.00  154.96
# 1  Apr  4 2019 12:00:00:000AM     469738.25  133.98
# 2  Jun 22 2020 12:00:00:000AM     375372.63  145.10
# 3  Aug  9 2019 12:00:00:000AM     336955.50  132.45
# 4  Jul 18 2019 12:00:00:000AM     375830.00  135.87

# %% [markdown]
# # Data Transformation

# %%
df_new['LAST_SALE_DATE'] = pd.to_datetime(df_new['LAST_SALE_DATE'], format="%b %d %Y %I:%M:%S:%f%p")

# Generating useful information from date values

df_new['SALE_DATE_YR'] = df_new['LAST_SALE_DATE'].dt.year
df_new['AGE_OF_HOUSE_AT_SALE'] = df_new['SALE_DATE_YR'] - df_new['YRBLT']
df_new['SALE_DATE_MNTH'] = df_new['LAST_SALE_DATE'].dt.month
df_new['SALE_DATE_DT'] = df_new['LAST_SALE_DATE'].dt.day
df_new.drop(['LAST_SALE_DATE', 'YRBLT', 'USPF'], axis=1, inplace=True)
df_new = pd.get_dummies(df_new)
df_new.head()
# Out:
#    ARCH  BEDROOMS  BATHROOMS  HALF_BATHROOMS  BASE_AREA  TOTAL_AREA  BASEMENT_AREA  BASEMENT_FINISHED_AREA  PARKING_AREA  YRBLT  PHYS  QUALITY_CODE  LOT_SIZE  LAND_VALUE  LAST_SALE_PRICE LAST_SALE_DATE  MARKET_VALUE    USPF
# 0  2STY       4.0        4.0             1.0       3622        3622           1645                      54           651   2012     8            45      0.22       58000           550000     2020-08-25     561275.00  154.96
# 1  2STY       6.0        4.0             1.0       3506        3506           1768                       0           630   2013     7            40      0.21       58000           435000     2019-04-04     469738.25  133.98
# 2  2STY       4.0        3.0             1.0       2587        2587           1180                      75           420   2007     8            40      0.21       58000           364900     2020-06-22     375372.63  145.10
# 3  2STY       4.0        2.0             1.0       2544        2544           1232                       0           400   2010    11            35      0.14       58000           315000     2019-08-09     336955.50  132.45
# 4  2STY       4.0        3.0             1.0       2766        2766           1291                      71           400   2008     8            35      0.18       58000           355000     2019-07-18     375830.00  135.87

# %%
from sklearn.model_selection import train_test_split

df_y = df_new['LAST_SALE_PRICE']
df_x = df_new.drop('LAST_SALE_PRICE', axis=1)

x_train, x_test, y_train, y_test = train_test_split(df_x, df_y, test_size = 0.25, random_state = 1)
print(f' Training dataset shape: {x_train.shape} | Testing dataset shape: {x_test.shape}')
# Out:
#  Training dataset shape: (219, 19) | Testing dataset shape: (74, 19)

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

model = LinearRegression()
model.fit(x_train, y_train)

# print(model.intercept_)
# print(model.coef_)
y_pred = model.predict(x_test)

df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(f'{df.head()} \n')

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))

# https://www.analyticsvidhya.com/blog/2021/05/all-you-need-to-know-about-your-first-machine-learning-model-linear-regression/
# https://www.analyticsvidhya.com/blog/2021/07/an-introduction-to-linear-regression/
# https://www.analyticsvidhya.com/blog/2021/06/getting-started-with-machine-learning%e2%80%8a-%e2%80%8aimplementing-linear-regression-from-scratch/
# Out:
#      Actual      Predicted
# 132  268000  269143.567689
# 268  484000  482166.755064
# 171  339000  333440.236480
# 62   330000  327566.313447
# 110  375000  376296.790437
#
# Mean Absolute Error: 2344.5230350433976
# Mean Squared Error: 8521105.699304821
# Root Mean Squared Error: 2919.093300890676

# %% [markdown]
# # Visualizations

# %%
numericCols = df_new.select_dtypes(include=['float64','int64'])

# Calculate Correlation
corr = numericCols.corr()
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
